# %% [markdown]
# https://tutorialedge.net/python/building-imdb-top-250-clone-pandas/
#
# https://github.com/PacktPublishing/Hands-On-Recommendation-Systems-with-Python/blob/master/Chapter3/Simple%20Recommender.ipynb
#
# https://www.kaggle.com/rounakbanik/the-movies-dataset

# %% [markdown]
# # The simple recommender

# %%
import pandas as pd
import numpy as np

data_path = '../data/MoviesDataset/'

df = pd.read_csv(data_path + 'movies_metadata_v2.csv', low_memory=False)
df.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /3Rfvhy1Nl6sSGJwyjb0QiZzZYlB.jpg
# 1  False  /6w31RRm2s2CK1r3xDLf12WgIaHa.jpg
# 2  False  /nh9gYaXHTNT9yylX10L9aGqFehy.jpg
# 3  False  /u4YN4GgyHT8vNhQEg67ImbxZftF.jpg
# 4  False  /lEsjVrGU21BeJjF5AF9EWsihDpw.jpg
#
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  {'id': 495527, 'name': 'Jumanji Collection', '...  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...  25000000
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride (St...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
#
#                                       homepage     id    imdb_id  \
# 0         http://toystory.disney.com/toy-story    862  tt0114709
# 1  http://www.sonypictures.com/movies/jumanji/   8844  tt0113497
# 2                                          NaN  15602  tt0113228
# 3                                          NaN  31357  tt0114885
# 4                                          NaN  11862  tt0113041
#
#   original_language               original_title  ... release_date    revenue  \
# 0                en                    Toy Story  ...   1995-10-30  373554033
# 1                en                      Jumanji  ...   1995-12-15  262797249
# 2                en             Grumpier Old Men  ...   1995-12-22   71500000
# 3                en            Waiting to Exhale  ...   1995-12-22   81452156
# 4                en  Father of the Bride Part II  ...   1995-12-08   76594107
#
#   runtime                                   spoken_languages    status  \
# 0    81.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1   104.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2   101.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3   127.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4   106.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          8.0      14752
# 1                      Jumanji  False          7.2       8612
# 2             Grumpier Old Men  False          6.5        271
# 3            Waiting to Exhale  False          6.3        109
# 4  Father of the Bride Part II  False          6.3        531
#
# [5 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['adult', 'backdrop_path', 'belongs_to_collection', 'budget', 'genres',
#        'homepage', 'id', 'imdb_id', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
#Calculate the number of votes garnered by the 80th percentile movie
m = df['vote_count'].quantile(0.95)
m
# Out:
# 1265.0

# %%
#Only consider movies longer than 45 minutes and shorter than 300 minutes
q_movies = df[(df['runtime'] >= 45) & (df['runtime'] <= 300)]

#Only consider movies that have garnered more than m votes
q_movies = q_movies[q_movies['vote_count'] >= m]

#Inspect the number of movies that made the cut
q_movies.shape
# Out:
# (2247, 25)

# %%
# Calculate C
C = df['vote_average'].mean()
C
# Out:
# 6.058819999999757

# %%
# Function to compute the IMDB weighted rating for each movie
def weighted_rating(x, m=m, C=C):
    v = x['vote_count']
    R = x['vote_average']
    # Compute the weighted score
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
# Compute the score using the weighted_rating function defined above
q_movies['score'] = q_movies.apply(weighted_rating, axis=1)

# %%
#Sort movies in descending order of their scores
q_movies = q_movies.sort_values('score', ascending=False)

#Print the top 25 movies
q_movies[['title', 'vote_count', 'vote_average', 'score', 'runtime', 'poster_path', 'overview']].head(25)
# Out:
#                                                    title  vote_count  \
# 314                             The Shawshank Redemption       20247
# 834                                        The Godfather       15155
# 12451                                    The Dark Knight       26332
# 292                                         Pulp Fiction       22211
# 351                                         Forrest Gump       21718
# 522                                     Schindler's List       12102
# 7000       The Lord of the Rings: The Return of the King       18683
# 15424                                          Inception       30394
# 22759                                       Interstellar       27200
# 1178                              The Godfather: Part II        9125
# 3030                                      The Green Mile       13147
# 45043                                         Fight Club       22984
# 2843                                          Fight Club       22981
# 5481                                       Spirited Away       12128
# 4863   The Lord of the Rings: The Fellowship of the Ring       20112
# 39934                                         Your Name.        8118
# 5814               The Lord of the Rings: The Two Towers       17370
# 2211                                   Life Is Beautiful       10636
# 1170                                          GoodFellas        9562
# 1154                             The Empire Strikes Back       13605
# 23547                                           Whiplash       11641
# 46                                                 Se7en       16162
# 1225                                  Back to the Future       15867
# 359                                        The Lion King       14703
# 2216                                  American History X        9160
#
#        vote_average     score  runtime                       poster_path  \
# 314             8.7  8.544822    142.0  /q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg
# 834             8.7  8.496697    175.0  /eEslKSwcqmiNS6va24Pbxf2UKmJ.jpg
# 12451           8.5  8.388200    152.0  /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 292             8.5  8.368574    154.0  /d5iIlFn5s0ImszYzBPb8JPIfbXD.jpg
# 351             8.5  8.365755    142.0  /saHP97rTPS5eLmrLQEcANmKrsFl.jpg
# 522             8.6  8.359717    195.0  /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg
# 7000            8.5  8.345329    201.0  /rCzpDGLbOoPwLjy3OAm5NUPOTrC.jpg
# 15424           8.4  8.306538    148.0  /9gk7adHYeDvHkCSEqAvQNLV5Uge.jpg
# 22759           8.4  8.296050    169.0  /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 1178            8.6  8.290863    202.0  /sSuQTCZwqKrNBNIsksO9IAUoWP9.jpg
# 3030            8.5  8.285912    189.0  /velWPhVMQeQKcxggNEU8YmIo52R.jpg
# 45043           8.4  8.277977    139.0  /pB8BM7pdSp6B6Ih7QZ4DrQ3PmJK.jpg
# 2843            8.4  8.277961    139.0  /pB8BM7pdSp6B6Ih7QZ4DrQ3PmJK.jpg
# 5481            8.5  8.269622    125.0  /39wmItIWsg5sZMyRUHLkWBcuVCM.jpg
# 4863            8.4  8.261582    179.0  /6oom5QYQ2yQTMJIbnvbkBL9cHo6.jpg
# 39934           8.6  8.257682    106.0  /q719jXXEzOoYaps6babgKnONONX.jpg
# 5814            8.4  8.241214    179.0  /5VTN0pR8gcqV3EPUHHfMGnJYN9L.jpg
# 2211            8.5  8.240737    116.0  /74hLDKjD5aGYOotO6esUVaeISa2.jpg
# 1170            8.5  8.215017    145.0  /6QMSLvU5ziIL2T6VrkaKzN2YkxK.jpg
# 1154            8.4  8.201007    124.0  /7BuH8itoSrLExs2YZSsM01Qk2no.jpg
# 23547           8.4  8.170723    107.0  /oPxnRhyAIzJKGUEdSiwTJQBa3NM.jpg
# 46              8.3  8.137460    127.0  /69Sns8WoET6CfaYlIkHbla4l7nC.jpg
# 1225            8.3  8.134661    116.0  /7lyBcpYB0Qt8gYhXYaEZUNlNQAv.jpg
# 359             8.3  8.122608     89.0  /sKCr78MXSLixwmZ8DyJLrpMsd15.jpg
# 2216            8.4  8.116153    119.0  /c2gsmSQ2Cqv8zosqKOCwRS0GFBS.jpg
#
#                                                 overview
# 314    Framed in the 1940s for the double murder of h...
# 834    Spanning the years 1945 to 1955, a chronicle o...
# 12451  Batman raises the stakes in his war on crime. ...
# 292    A burger-loving hit man, his philosophical par...
# 351    A man with a low IQ has accomplished great thi...
# 522    The true story of how businessman Oskar Schind...
# 7000   Aragorn is revealed as the heir to the ancient...
# 15424  Cobb, a skilled thief who commits corporate es...
# 22759  The adventures of a group of explorers who mak...
# 1178   In the continuing saga of the Corleone crime f...
# 3030   A supernatural tale set on death row in a Sout...
# 45043  A ticking-time-bomb insomniac and a slippery s...
# 2843   A ticking-time-bomb insomniac and a slippery s...
# 5481   A young girl, Chihiro, becomes trapped in a st...
# 4863   Young hobbit Frodo Baggins, after inheriting a...
# 39934  High schoolers Mitsuha and Taki are complete s...
# 5814   Frodo and Sam are trekking to Mordor to destro...
# 2211   A touching story of an Italian book seller of ...
# 1170   The true story of Henry Hill, a half-Irish, ha...
# 1154   The epic saga continues as Luke Skywalker, in ...
# 23547  Under the direction of a ruthless instructor, ...
# 46     Two homicide detectives are on a desperate hun...
# 1225   Eighties teenager Marty McFly is accidentally ...
# 359    A young lion prince is cast out of his pride b...
# 2216   Derek Vineyard is paroled after serving 3 year...

# %% [markdown]
# ### Prepare function for Streamlit

# %%
df = pd.read_csv(data_path + 'movies_metadata.csv', low_memory=False)

#Input from user in Streamlit
percentile = 0.95

# %%
def simple_recommender(df, percentile):
    movies = df.copy()
    
    #Compute the values of C and m for the filtered movies
    C = movies['vote_average'].mean()
    m = movies['vote_count'].quantile(percentile)
    
    #Only consider movies longer than 45 minutes and shorter than 300 minutes
    q_movies = movies[(movies['runtime'] >= 45) & (movies['runtime'] <= 300)]
    
    #Only consider movies that have higher than m votes. Save this in a new dataframe q_movies
    q_movies = q_movies.copy().loc[q_movies['vote_count'] >= m]
    
    #Calculate score using the IMDB formula
    q_movies['score'] = q_movies.apply(lambda x: (x['vote_count']/(x['vote_count']+m) * x['vote_average']) 
                                                   + (m/(m+x['vote_count']) * C),
                                       axis=1)

    #Sort movies in descending order of their scores
    q_movies = q_movies.sort_values('score', ascending=False)
    
    return q_movies

# %%
#Print the top 25 movies
data = simple_recommender(df, percentile)[['title', 'vote_count', 'vote_average', 'score', 'runtime', 'poster_path', 'overview']].head(25)

# %%
data.loc[314]
# Out:
# title                                    The Shawshank Redemption
# vote_count                                                 8358.0
# vote_average                                                  8.5
# score                                                    8.357746
# runtime                                                     142.0
# poster_path                      /9O7gLzmreU0nGkIB6K3BsJbzvNv.jpg
# overview        Framed in the 1940s for the double murder of h...
# Name: 314, dtype: object

# %%
for idx in data.index:
    print(data.loc[idx, 'poster_path'])
# Out:
# /9O7gLzmreU0nGkIB6K3BsJbzvNv.jpg
# /rPdtLWNsZmAtoZl9PK7S2wE3qiS.jpg
# /1hRoyzDtpgMU7Dz4JF22RANzQO7.jpg
# /adw6Lq9FiC9zjYEpOqfq03ituwp.jpg
# /dM2w364MScsjFf8pfMbaWUcWrR.jpg
# /yE5d3BUhE8hCnkMUJOo1QDoOGNz.jpg
# /yPisjyLweCl1tbgwgtzBCNCBle.jpg
# /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg
# /ynXoOxmDHNQ4UAy0oU6avW71HVW.jpg
# /6u1fYtxG5eqjhtCPDx04pJphQRW.jpg
# /qmDpIHrmpJINaRKAfWQfftjCdyi.jpg
# /f7DImXDebOs148U4uPjI61iDvaK.jpg
# /4mFsNQwbD0F237Tx7gAPotd0nbJ.jpg
# /nBNZadXqJSdt05SHLqgT0HuC5Gm.jpg
# /bVq65huQ8vHDd1a4Z37QtuyEvpA.jpg
# /uexxR7Kw1qYbZk0RYaF9Rx5ykbj.jpg
# /gE8S02QUOhVnAmYu4tcrBlMTujz.jpg
# /2Sns5oMb356JNdBHgBETjIpRYy9.jpg
# /3yJUlOtVa09CYJocwBU8eAryja0.jpg
# /btTdmkgIvOi0FFip1sPuZI2oQG6.jpg
# /8zw8IL4zEPjkh8Aysdcd0FwGMb0.jpg
# /hAPeXBdGDGmXRPj4OZZ0poH65Iu.jpg
# /81d8oyEFgj7FlxJqSDXWr8JH8kV.jpg
# /bxVxZb5O9OxCO0oRUNdCnpy9NST.jpg
# /fXepRAYOx1qC3wju7XdDGx60775.jpg

# %% [markdown]
# ## Investigating links for movies MovieLens, IMDb, TMDb

# %%
links = pd.read_csv(path + '/links.csv', low_memory=False)
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
# imdb_id should has tt + 8 digitis. Ex. for Toy Story:
# https://www.imdb.com/title/tt0114709
# https://movielens.org/movies/1
# https://www.themoviedb.org/movie/862

imdb_path = 'https://www.imdb.com/title/'
movielens_path = 'https://movielens.org/movies/'
tmbd_path = 'https://www.themoviedb.org/movie/'
