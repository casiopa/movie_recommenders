# %% [markdown]
# https://tutorialedge.net/python/building-imdb-top-250-clone-pandas/
#
# https://github.com/PacktPublishing/Hands-On-Recommendation-Systems-with-Python/blob/master/Chapter3/Simple%20Recommender.ipynb
#
# https://www.kaggle.com/rounakbanik/the-movies-dataset

# %% [markdown]
# # The simple recommender

# %%
import pandas as pd
import numpy as np

path = 'data/MoviesDataset/'

df = pd.read_csv(path + '/movies_metadata.csv', low_memory=False)
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
#Calculate the number of votes garnered by the 80th percentile movie
m = df['vote_count'].quantile(0.95)
m
# Out:
# 434.0

# %%
#Only consider movies longer than 45 minutes and shorter than 300 minutes
q_movies = df[(df['runtime'] >= 45) & (df['runtime'] <= 300)]

#Only consider movies that have garnered more than m votes
q_movies = q_movies[q_movies['vote_count'] >= m]

#Inspect the number of movies that made the cut
q_movies.shape
# Out:
# (2269, 24)

# %%
# Calculate C
C = df['vote_average'].mean()
C
# Out:
# 5.618207215133889

# %%
# Function to compute the IMDB weighted rating for each movie
def weighted_rating(x, m=m, C=C):
    v = x['vote_count']
    R = x['vote_average']
    # Compute the weighted score
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
# Compute the score using the weighted_rating function defined above
q_movies['score'] = q_movies.apply(weighted_rating, axis=1)

# %%
#Sort movies in descending order of their scores
q_movies = q_movies.sort_values('score', ascending=False)

#Print the top 25 movies
q_movies[['title', 'vote_count', 'vote_average', 'score', 'runtime', 'poster_path', 'overview']].head(25)
# Out:
#                                                    title  vote_count  \
# 314                             The Shawshank Redemption      8358.0
# 834                                        The Godfather      6024.0
# 12481                                    The Dark Knight     12269.0
# 2843                                          Fight Club      9678.0
# 292                                         Pulp Fiction      8670.0
# 351                                         Forrest Gump      8147.0
# 522                                     Schindler's List      4436.0
# 23673                                           Whiplash      4376.0
# 5481                                       Spirited Away      3968.0
# 1154                             The Empire Strikes Back      5998.0
# 15480                                          Inception     14075.0
# 2211                                   Life Is Beautiful      3643.0
# 18465                                   The Intouchables      5410.0
# 22879                                       Interstellar     11187.0
# 1178                              The Godfather: Part II      3418.0
# 7000       The Lord of the Rings: The Return of the King      8226.0
# 289                               Leon: The Professional      4293.0
# 1152                     One Flew Over the Cuckoo's Nest      3001.0
# 3030                                      The Green Mile      4166.0
# 256                                            Star Wars      6778.0
# 46                                                 Se7en      5915.0
# 1170                                          GoodFellas      3211.0
# 1176                                              Psycho      2405.0
# 4863   The Lord of the Rings: The Fellowship of the Ring      8892.0
# 2216                                  American History X      3120.0
#
#        vote_average     score  runtime                       poster_path  \
# 314             8.5  8.357746    142.0  /9O7gLzmreU0nGkIB6K3BsJbzvNv.jpg
# 834             8.5  8.306334    175.0  /rPdtLWNsZmAtoZl9PK7S2wE3qiS.jpg
# 12481           8.3  8.208376    152.0  /1hRoyzDtpgMU7Dz4JF22RANzQO7.jpg
# 2843            8.3  8.184899    139.0  /adw6Lq9FiC9zjYEpOqfq03ituwp.jpg
# 292             8.3  8.172155    154.0   /dM2w364MScsjFf8pfMbaWUcWrR.jpg
# 351             8.2  8.069421    142.0  /yE5d3BUhE8hCnkMUJOo1QDoOGNz.jpg
# 522             8.3  8.061007    195.0   /yPisjyLweCl1tbgwgtzBCNCBle.jpg
# 23673           8.3  8.058025    105.0  /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg
# 5481            8.3  8.035598    125.0  /ynXoOxmDHNQ4UAy0oU6avW71HVW.jpg
# 1154            8.2  8.025793    124.0  /6u1fYtxG5eqjhtCPDx04pJphQRW.jpg
# 15480           8.1  8.025763    148.0  /qmDpIHrmpJINaRKAfWQfftjCdyi.jpg
# 2211            8.3  8.014521    116.0  /f7DImXDebOs148U4uPjI61iDvaK.jpg
# 18465           8.2  8.008265    112.0  /4mFsNQwbD0F237Tx7gAPotd0nbJ.jpg
# 22879           8.1  8.007315    169.0  /nBNZadXqJSdt05SHLqgT0HuC5Gm.jpg
# 1178            8.3  7.997846    200.0  /bVq65huQ8vHDd1a4Z37QtuyEvpA.jpg
# 7000            8.1  7.975624    201.0  /uexxR7Kw1qYbZk0RYaF9Rx5ykbj.jpg
# 289             8.2  7.962958    110.0  /gE8S02QUOhVnAmYu4tcrBlMTujz.jpg
# 1152            8.3  7.961165    133.0  /2Sns5oMb356JNdBHgBETjIpRYy9.jpg
# 3030            8.2  7.956413    189.0  /3yJUlOtVa09CYJocwBU8eAryja0.jpg
# 256             8.1  7.950652    121.0  /btTdmkgIvOi0FFip1sPuZI2oQG6.jpg
# 46              8.1  7.930352    127.0  /8zw8IL4zEPjkh8Aysdcd0FwGMb0.jpg
# 1170            8.2  7.892593    145.0  /hAPeXBdGDGmXRPj4OZZ0poH65Iu.jpg
# 1176            8.3  7.890032    109.0  /81d8oyEFgj7FlxJqSDXWr8JH8kV.jpg
# 4863            8.0  7.889160    178.0  /bxVxZb5O9OxCO0oRUNdCnpy9NST.jpg
# 2216            8.2  7.884722    119.0  /fXepRAYOx1qC3wju7XdDGx60775.jpg
#
#                                                 overview
# 314    Framed in the 1940s for the double murder of h...
# 834    Spanning the years 1945 to 1955, a chronicle o...
# 12481  Batman raises the stakes in his war on crime. ...
# 2843   A ticking-time-bomb insomniac and a slippery s...
# 292    A burger-loving hit man, his philosophical par...
# 351    A man with a low IQ has accomplished great thi...
# 522    The true story of how businessman Oskar Schind...
# 23673  Under the direction of a ruthless instructor, ...
# 5481   A ten year old girl who wanders away from her ...
# 1154   The epic saga continues as Luke Skywalker, in ...
# 15480  Cobb, a skilled thief who commits corporate es...
# 2211   A touching story of an Italian book seller of ...
# 18465  A true story of two men who should never have ...
# 22879  Interstellar chronicles the adventures of a gr...
# 1178   In the continuing saga of the Corleone crime f...
# 7000   Aragorn is revealed as the heir to the ancient...
# 289    Leon, the top hit man in New York, has earned ...
# 1152   While serving time for insanity at a state men...
# 3030   A supernatural tale set on death row in a Sout...
# 256    Princess Leia is captured and held hostage by ...
# 46     Two homicide detectives are on a desperate hun...
# 1170   The true story of Henry Hill, a half-Irish, ha...
# 1176   When larcenous real estate clerk Marion Crane ...
# 4863   Young hobbit Frodo Baggins, after inheriting a...
# 2216   Derek Vineyard is paroled after serving 3 year...

# %% [markdown]
# ## Investigating links for movies MovieLens, IMDb, TMDb

# %%
links = pd.read_csv(path + '/links.csv', low_memory=False)
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
# imdb_id should has tt + 8 digitis. Ex. for Toy Story:
# https://www.imdb.com/title/tt0114709
# https://movielens.org/movies/1
# https://www.themoviedb.org/movie/862

imdb_path = 'https://www.imdb.com/title/'
movielens_path = 'https://movielens.org/movies/'
tmbd_path = 'https://www.themoviedb.org/movie/'
